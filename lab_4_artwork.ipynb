# %%
import pandas as pd

# %%
artwork_df = pd.read_csv('/Users/catalinacruceanu/Desktop/collection-master/artwork_data.csv', delimiter=",", encoding='utf-8')
# Out:
# /var/folders/5d/71sszjgj185_p24zygj5cx3r0000gn/T/ipykernel_42906/721893538.py:1: DtypeWarning: Columns (9,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   artwork_df = pd.read_csv('/Users/catalinacruceanu/Desktop/collection-master/artwork_data.csv', delimiter=",", encoding='utf-8')

# %%
artwork_df.sample(10)
# Out:
#           id accession_number                          artist artistRole  \
# 1970   97394          AR00233                    Warhol, Andy     artist
# 4244   28766           D01359  Turner, Joseph Mallord William     artist
# 31792  56427           D29156  Turner, Joseph Mallord William     artist
# 53079  20550           P77563                  Hockney, David     artist
# 1044     860           A01048               Beerbohm, Sir Max     artist
# 14249  38803           D11428  Turner, Joseph Mallord William     artist
# 20966  45534           D18179  Turner, Joseph Mallord William     artist
# 9911   34453           D07063  Turner, Joseph Mallord William     artist
# 38671  63329           D36243  Turner, Joseph Mallord William     artist
# 44727   1345           P01372                  Boshier, Derek     artist
#
#        artistId                                              title  dateText  \
# 1970       2121                                          Hamburger    1985–6
# ...

# %%
artwork_df.medium
# Out:
# 0        Watercolour, ink, chalk and graphite on paper....
# 1                                        Graphite on paper
# 2              Graphite on paper. Verso: graphite on paper
# 3                                        Graphite on paper
# 4                                  Line engraving on paper
#                                ...
# 69196     Perspex, Wood, hairpiece, tampon and human blood
# 69197    Wood, Perspex, plastic, photograph on paper, t...
# 69198                                 Soap and glass beads
# 69199                                     Gallery lighting
# 69200                                  Oil paint on canvas
# Name: medium, Length: 69201, dtype: object

# %%
#When was the last acquisition made?
artwork_df.acquisitionYear.max()
# Out:
# 2013.0

# %%
#Show only the acquisitions made after the year 2000. 
artwork_df[artwork_df.acquisitionYear > 2000]
# Out:
#            id accession_number              artist artistRole  artistId  \
# 1738    98171          AR00001          Katz, Alex     artist      1386
# 1739    98172          AR00002          Katz, Alex     artist      1386
# 1740    98173          AR00003          Katz, Alex     artist      1386
# 1741    98174          AR00004          Katz, Alex     artist      1386
# 1742    98175          AR00005          Katz, Alex     artist      1386
# ...       ...              ...                 ...        ...       ...
# 69196  122960           T13865  P-Orridge, Genesis     artist     16646
# 69197  122961           T13866  P-Orridge, Genesis     artist     16646
# 69198  121181           T13867        Hatoum, Mona     artist      2365
# 69199  112306           T13868       Creed, Martin     artist      2760
# 69200  127035           T13869   Brunias, Agostino     artist      3824
#
#                                            title dateText  \
# ...

# %%
#Show only the artworks painted with oil paint on canvas. 
artwork_df[artwork_df.medium == 'Oil paint on canvas']
# Out:
#            id accession_number                  artist artistRole  artistId  \
# 737      8609           A00741  Leslie, Charles Robert     artist       346
# 833     12386           A00837    Reynolds, Sir Joshua     artist       444
# 835     12749           A00839  Rooke, Thomas Matthews     artist       458
# 836     12750           A00840  Rooke, Thomas Matthews     artist       458
# 837     12751           A00841  Rooke, Thomas Matthews     artist       458
# ...       ...              ...                     ...        ...       ...
# 69144  127717           T13813          Cordell, Magda     artist      2392
# 69152  124974           T13821            Sillman, Amy     artist     16982
# 69176  122545           T13845            Kirkeby, Per     artist      2238
# 69192  123620           T13861           Sterne, Hedda     artist     16798
# 69200  127035           T13869       Brunias, Agostino     artist      3824
#
# ...

# %%
artwork_df.groupby('artist').medium.describe()
# Out:
#                        count unique  \
# artist
# ?British School            1      1
# Abakanowicz, Magdalena     4      4
# Abbey, Edwin Austin        6      1
# Abbott, Berenice           3      1
# Abbott, Lemuel Francis     2      1
# ...                      ...    ...
# Zuloaga, Ignacio           1      1
# Zyw, Aleksander            1      1
# di Suvero, Mark            1      1
# van Elk, Ger               2      2
# Štyrský, Jindrich          2      1
#
#                                                                      top freq
# artist
# ?British School                                         Oil paint on oak    1
# Abakanowicz, Magdalena  Burlap, cotton gauze, hemp rope, nylon and sisal    1
# Abbey, Edwin Austin                                         Ink on paper    6
# Abbott, Berenice               Photograph, gelatin silver print on paper    3
# Abbott, Lemuel Francis                               Oil paint on canvas    2
# ...

# %%
acquisition_filter = artwork_df['acquisitionYear'] >= 2005.0

# %%
acquisition_df = artwork_df[acquisition_filter]

# %%
#Count artworks collected by the museum starting 2005.
acquisition_df.groupby('acquisitionYear')['title'].count()
# Out:
# acquisitionYear
# 2005.0     333
# 2006.0     239
# 2007.0     333
# 2008.0     787
# 2009.0    1364
# 2010.0     392
# 2011.0     320
# 2012.0     514
# 2013.0     458
# Name: title, dtype: int64

# %%
#I was only interested in the acquisition year histogram. 
acquisition_df.hist(figsize=(10,10))
# Out:
# array([[<AxesSubplot:title={'center':'id'}>,
#         <AxesSubplot:title={'center':'artistId'}>],
#        [<AxesSubplot:title={'center':'acquisitionYear'}>,
#         <AxesSubplot:title={'center':'depth'}>]], dtype=object)
